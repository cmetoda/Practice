# %%
import pandas as pd
import pymysql
import numpy as np
import matplotlib
from sqlalchemy import create_engine

# %%
cnx = create_engine('mysql+pymysql://fullscale:Test12345!@127.0.0.1/leadsgeneration')    
keywords_location = pd.read_sql('SELECT * FROM keywords_location', cnx) #read the entire table

# %%
keywords_location
# Out:
#     pk            city state_abbreviation          date_added  \
# 0    1         Atlanta                 GA 2020-01-23 15:11:32
# 1    2          Boston                 MA 2020-01-23 15:11:32
# 2    3       Charlotte                 NC 2020-01-23 15:11:32
# 3    4         Chicago                 IL 2020-01-23 15:11:32
# 4    5      Cincinnati                 OH 2020-01-23 15:11:32
# 5    6       Cleveland                 OH 2020-01-23 15:11:32
# 6    7        Columbus                 OH 2020-01-23 15:11:32
# 7    8          Dallas                 TX 2020-01-23 15:11:32
# 8    9          Denver                 CO 2020-01-23 15:11:32
# 9   10         Detroit                 MI 2020-01-23 15:11:32
# 10  11         Houston                 TX 2020-01-23 15:11:32
# 11  12    Indianapolis                 IN 2020-01-23 15:11:32
# 12  13     Kansas City                 MO 2020-01-23 15:11:32
# 13  14       Las Vegas                 NV 2020-01-23 15:11:32
# ...
